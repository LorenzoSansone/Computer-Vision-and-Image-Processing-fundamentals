# %% [markdown]
# # **Introduction to OpenCV**
# ## Image Processing and Computer Vision

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
IMG_PATH = 
cv2.imread()
